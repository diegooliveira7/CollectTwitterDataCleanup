# %%
# !pip3 install --upgrade git+https://github.com/JustAnotherArchivist/snscrape.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to /tmp/pip-req-build-6exmox5f
#   Running command git clone --filter=blob:none --quiet https://github.com/JustAnotherArchivist/snscrape.git /tmp/pip-req-build-6exmox5f
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit 786815dd05681e2421cd03aa9acf5ab5c773bce9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for snscrape: filename=snscrape-0.6.2.20230321.dev13+g786815d-py3-none-any.whl size=73302 sha256=311d0a2ed711e741ae4fa8ef06cbd2eccbddb9896c8f567e0ae7b8d4634e5ba8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ipx7ppor/wheels/05/e9/f7/57056e7c7e44b1feed932fa49fdec9d706c4f563e37160ab74
# Successfully built snscrape
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
#Escoteiro until:2022-09-30 since:2022-01-01
query = "(Escoteiro OR Escotismo OR Desbravadores OR Escoteiros OR escotismo OR desbravador OR dbv OR Campori) lang:pt until:2023-05-05 since:2020-01-01"
tweets = []
limit = 100000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    # print(vars(tweet))
    # break
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date, tweet.username, tweet.content, tweet.id])
        print(tweet.content)
        
df = pd.DataFrame(tweets, columns=['Date', 'User', 'Tweet', 'ID'])
# Out:
# <ipython-input-15-0df84e913f25>:13: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.username, tweet.content, tweet.id])
# <ipython-input-15-0df84e913f25>:13: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.username, tweet.content, tweet.id])
# <ipython-input-15-0df84e913f25>:14: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   print(tweet.content)
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1653743823632097280-2b2fbd4387397a15'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1654587024060424192-2b2f64fc79d8d1ac'
# WARNING:snscrape.modules.twitter:Skipping unrecognised entry ID: 'promoted-tweet-1591490305387372544-2b2ff80766fed21d'
# é absurdo como eu sou apaixonada pelo escotismo
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13330 entries, 0 to 13329
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    13330 non-null  datetime64[ns, UTC]
#  1   User    13330 non-null  object
#  2   Tweet   13330 non-null  object
#  3   ID      13330 non-null  int64
# dtypes: datetime64[ns, UTC](1), int64(1), object(2)
# memory usage: 416.7+ KB

# %%
df.to_excel(tweets_escot_dbv_2023-05-05_2021-01-01_excel)
# Out:
#   File "<ipython-input-20-d6d36a298c9c>", line 1
#     df.to_excel(tweets_escot_dbv_2023-05-05_2021-01-01_excel)
#                                       ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers
