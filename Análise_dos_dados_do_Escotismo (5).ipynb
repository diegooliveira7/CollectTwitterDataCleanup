# %%
#Bibliotecas
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #1 - Criação do DB (Não usar mais)

# %%
#Carregar dados
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DB/TCC/tweets_escot_dbv_2023-05-05_2021-01-01.csv", engine='python')

# %%
df

# %%
from random import randrange, uniform
print(randrange(0, 13332)) #faixa de inteiro
# Out:
# 8138

# %%
dff = pd.DataFrame(columns=['Date', 'User', 'Tweet', 'ID', 'Binário', 'Ternário'])
dff
# Out:
# Empty DataFrame
# Columns: [Date, User, Tweet, ID, Binário, Ternário]
# Index: []

# %%
dff.append(df.iloc[1], ignore_index=True)
# Out:
# <ipython-input-8-238efca6dfc9>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dff.append(df.iloc[1], ignore_index=True)
#                         Date        User  \
# 0  2023-05-04 23:41:15+00:00  Charloutt_
#
#                                                Tweet            ID Unnamed: 0
# 0  Campori Osório 2022, um dos momentos da minha ...  1.654270e+18          1

# %%
df.iloc[1]
nova_linha = pd.DataFrame.from_records({'Date': df.iloc[1]['Date'], 'User': df.iloc[1]['User'], 'Tweet': df.iloc[1]['Tweet'], 'ID': df.iloc[1]['ID']}, index=[0])
dff = pd.concat([dff, nova_linha])
#dff.concat(nova_linha)
dff
# Out:
#                         Date        User  \
# 0  2023-05-04 23:41:15+00:00  Charloutt_
# 0  2023-05-04 23:41:15+00:00  Charloutt_
#
#                                                Tweet            ID
# 0  Campori Osório 2022, um dos momentos da minha ...  1.654270e+18
# 0  Campori Osório 2022, um dos momentos da minha ...  1.654270e+18

# %%
#dff = pd.DataFrame()
count = 0
while count < 100:
  nova_linha = pd.DataFrame.from_records({'Date': df.iloc[count]['Date'], 'User': df.iloc[count]['User'], 'Tweet': df.iloc[count]['Tweet'], 'ID': df.iloc[count]['ID']}, index=[count])
  dff = pd.concat([dff, nova_linha])
  count = count + 1

# %%
dff
# Out:
#                          Date            User  \
# 0   2023-05-04 23:56:16+00:00         calotey
# 1   2023-05-04 23:41:15+00:00      Charloutt_
# 2   2023-05-04 23:40:07+00:00      sorenzitos
# 3   2023-05-04 22:55:38+00:00    lovers_ranpo
# 4   2023-05-04 22:40:02+00:00      _Wallkiri_
# ..                        ...             ...
# 95  2023-05-03 22:15:55+00:00    mothisburned
# 96  2023-05-03 21:45:50+00:00   StarLight527w
# 97  2023-05-03 21:44:12+00:00        Noryzin2
# 98  2023-05-03 21:43:20+00:00  xichenlovepage
# 99  2023-05-03 21:41:50+00:00      Mathsukaze
#
#                                                 Tweet            ID Binário  \
# 0     é absurdo como eu sou apaixonada pelo escotismo  1.654274e+18     NaN
# 1   Campori Osório 2022, um dos momentos da minha ...  1.654270e+18     NaN
# 2   @ToinPierre Desbravador preservação, pela, bai...  1.654270e+18     NaN
# 3   @alyss0nz @i4geto É uma quantidade absurda e d...  1.654259e+18     NaN
# 4   @TalesMendes15 Lado bom esse mesmo, março e o ...  1.654255e+18     NaN
# ..                                                ...           ...     ...
# 95  desbravador(a) x sampo é esquisito em quesito ...  1.653886e+18     NaN
# 96  Oque é que nossos desbravadores tem de tão esp...  1.653879e+18     NaN
# 97  @eumechamonando Eu consegui levando natasha, h...  1.653878e+18     NaN
# 98                       vou sair dos escoteiros acho  1.653878e+18     NaN
# 99  @Isabell05916144 Pode deixar, o Desbravador nã...  1.653878e+18     NaN
#
#    Ternário
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 95      NaN
# 96      NaN
# 97      NaN
# 98      NaN
# 99      NaN
#
# [100 rows x 6 columns]

# %%
dff.iloc[0]['Tweet']
# Out:
# 'é absurdo como eu sou apaixonada pelo escotismo'

# %%
dff.iloc[0]['Binário'] = 1
# Out:
# <ipython-input-16-8e5d21d21f68>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dff.iloc[0]['Binário'] = 1

# %%
#writer = pd.ExcelWriter('try_xlsxwriter.xlsx')
dff.to_excel('testep.xlsx')

# %% [markdown]
# #2 - Testando os modelos

# %%
#Carregar dados
dfClass = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/DB/testep1000_te.csv", engine='python')
dfClass
# Out:
#       Unnamed: 0                       Date             User  \
# 0              0  2023-05-04 23:41:15+00:00       Charloutt_
# 1              0  2023-05-04 23:56:16+00:00          calotey
# 2              1  2023-05-04 23:41:15+00:00       Charloutt_
# 3              2  2023-05-04 23:40:07+00:00       sorenzitos
# 4              3  2023-05-04 22:55:38+00:00     lovers_ranpo
# ...          ...                        ...              ...
# 996          995  2023-04-24 00:27:09+00:00          _missun
# 997          996  2023-04-24 00:25:13+00:00         hyagocos
# 998          997  2023-04-24 00:03:56+00:00   grosangeladias
# 999          998  2023-04-23 23:56:52+00:00          aclawrs
# 1000         999  2023-04-23 23:54:54+00:00  isacachinhos957
#
#                                                   Tweet           ID  Binário  \
# 0     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 1       é absurdo como eu sou apaixonada pelo escotismo  1,65427E+18        1
# 2     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 3     @ToinPierre Desbravador preservação, pela, bai...  1,65427E+18        0
# 4     @alyss0nz @i4geto É uma quantidade absurda e d...  1,65426E+18        0
# ...                                                 ...          ...      ...
# 996   Chorando com todas as publicações do dia do es...   1,6503E+18        1
# 997   A única parte ruim desse fds é que perdi a con...  1,65029E+18        0
# 998   @Escoteiros comida mateira com uma escoteira, ...  1,65029E+18        1
# 999                      hj é dia do escoteiro :( q sdd  1,65029E+18        1
# 1000  Minha prima linda(que nao esta falando comigo ...  1,65029E+18        1
#
#       Ternário
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 996        NaN
# 997        NaN
# 998        NaN
# 999        NaN
# 1000       NaN
#
# [1001 rows x 7 columns]

# %%
# !pip3 install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.33.1-py3-none-any.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 24.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.17.1-py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 51.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.17.1 safetensors-0.3.3 tokenizers-0.13.3 transformers-4.33.1

# %%
from transformers import pipeline

# %%
#Correção do 3 para 2
count = 0;
for tweet in dfClass['Ternário']:
  if (tweet == 3):
    dfClass['Ternário'][count] = 2
  count = count + 1;
# Out:
# <ipython-input-5-d6a5b23aa9e6>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['Ternário'][count] = 2

# %%
##https://huggingface.co/philschmid/distilbert-base-multilingual-cased-sentiment-2?text=I+like+you.+I+love+you
from transformers import pipeline
unmasker = pipeline(model='philschmid/distilbert-base-multilingual-cased-sentiment-2')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/814 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
dfClass['teste001'] = 1 #Adicionando uma coluna a mais

# %%
count = 0
for tweet in dfClass['Tweet']:
  tweet_status = unmasker(str(tweet))

  if (tweet_status[0]['label'] == 'positive'):
    dfClass['teste001'][count] = 1
  elif (tweet_status[0]['label'] == 'negative'):
    dfClass['teste001'][count] = 0
  else:
    dfClass['teste001'][count] = 2

  #dfClass['teste001'][count] = tweet_status[0]['label'].eguals('')
  count = count + 1
# Out:
# <ipython-input-11-16ad27761736>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste001'][count] = 1
# <ipython-input-11-16ad27761736>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste001'][count] = 0
# <ipython-input-11-16ad27761736>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste001'][count] = 2

# %%
dfClass
# Out:
#       Unnamed: 0                       Date             User  \
# 0              0  2023-05-04 23:41:15+00:00       Charloutt_
# 1              0  2023-05-04 23:56:16+00:00          calotey
# 2              1  2023-05-04 23:41:15+00:00       Charloutt_
# 3              2  2023-05-04 23:40:07+00:00       sorenzitos
# 4              3  2023-05-04 22:55:38+00:00     lovers_ranpo
# ...          ...                        ...              ...
# 996          995  2023-04-24 00:27:09+00:00          _missun
# 997          996  2023-04-24 00:25:13+00:00         hyagocos
# 998          997  2023-04-24 00:03:56+00:00   grosangeladias
# 999          998  2023-04-23 23:56:52+00:00          aclawrs
# 1000         999  2023-04-23 23:54:54+00:00  isacachinhos957
#
#                                                   Tweet           ID  Binário  \
# 0     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 1       é absurdo como eu sou apaixonada pelo escotismo  1,65427E+18        1
# 2     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 3     @ToinPierre Desbravador preservação, pela, bai...  1,65427E+18        1
# 4     @alyss0nz @i4geto É uma quantidade absurda e d...  1,65426E+18        0
# ...                                                 ...          ...      ...
# 996   Chorando com todas as publicações do dia do es...   1,6503E+18        1
# 997   A única parte ruim desse fds é que perdi a con...  1,65029E+18        0
# 998   @Escoteiros comida mateira com uma escoteira, ...  1,65029E+18        1
# 999                      hj é dia do escoteiro :( q sdd  1,65029E+18        0
# 1000  Minha prima linda(que nao esta falando comigo ...  1,65029E+18        1
#
#       Ternário  teste001  teste002
# 0          NaN         1         1
# 1          NaN         0         0
# 2          NaN         1         1
# 3          NaN         0         0
# 4          NaN         0         0
# ...        ...       ...       ...
# 996        NaN         1         0
# 997        NaN         1         2
# 998        NaN         0         1
# 999        NaN         1         1
# 1000       NaN         1         1
#
# [1001 rows x 9 columns]

# %%
#Calcular a acertividade
count = 0
countt = 0
while (countt < 1000):
  if (dfClass.iloc[countt]['Binário'] == dfClass.iloc[countt]['teste001']):
    count = count + 1
  countt = countt + 1

count
# Out:
# 511

# %%
## ?
unmasker002 = pipeline(model='philschmid/distilbert-base-multilingual-cased-sentiment')
unmasker002("Feliz aniversário")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/814 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'label': 'positive', 'score': 0.9602950811386108}]

# %%
dfClass['teste002'] = 1
count = 0

for tweet in dfClass['Tweet']:
  tweet_status = unmasker002(str(tweet))

  if (tweet_status[0]['label'] == 'positive'):
    dfClass['teste002'][count] = 1
  elif (tweet_status[0]['label'] == 'negative'):
    dfClass['teste002'][count] = 0
  else:
    dfClass['teste002'][count] = 2
  count = count + 1
# Out:
# <ipython-input-14-320c94c8033f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste002'][count] = 1
# <ipython-input-14-320c94c8033f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste002'][count] = 0
# <ipython-input-14-320c94c8033f>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste002'][count] = 2

# %%
count = 0
countt = 0
while (countt < 1000):
  if (dfClass.iloc[countt]['Binário'] == dfClass.iloc[countt]['teste002']):
    count = count + 1
  countt = countt + 1

count
# Out:
# 522

# %%
##https://https://huggingface.co/Chirayu/mt5-multilingual-sentiment
unmasker003 = pipeline(model='Chirayu/mt5-multilingual-sentiment')
unmasker003("Feliz aniversário")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/407 [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/8.33M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# [{'generated_text': 'Positive'}]

# %%
dfClass['teste003'] = 1
count = 0

for tweet in dfClass['Tweet']:
  tweet_status = unmasker003(str(tweet))

  if (tweet_status[0]['generated_text'] == 'Positive'):
    dfClass['teste003'][count] = 1
  elif (tweet_status[0]['generated_text'] == 'Negative'):
    dfClass['teste003'][count] = 0
  else:
    dfClass['teste003'][count] = 2
  count = count + 1
# Out:
# <ipython-input-6-11cf3e267c1a>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste003'][count] = 1
# <ipython-input-6-11cf3e267c1a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste003'][count] = 0

# %%
count = 0
countt = 0
while (countt < 1000):
  if (dfClass.iloc[countt]['Binário'] == dfClass.iloc[countt]['teste003']):
    count = count + 1
  countt = countt + 1

count
# Out:
# 873

# %%
##https://huggingface.co/rohanrajpal/bert-base-multilingual-codemixed-cased-sentiment
unmasker004 = pipeline(model='rohanrajpal/bert-base-multilingual-codemixed-cased-sentiment')
unmasker004("Feliz aniversário")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/828 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/712M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'label': 'LABEL_2', 'score': 0.9610565304756165}]

# %%
dfClass['teste004'] = 1
count = 0

for tweet in dfClass['Tweet']:
  tweet_status = unmasker004(str(tweet))

  if (tweet_status[0]['label'] == 'LABEL_2'):
    dfClass['teste004'][count] = 1
  elif (tweet_status[0]['label'] == 'LABEL_0'):
    dfClass['teste004'][count] = 0
  else:
    dfClass['teste004'][count] = 2
  count = count + 1
# Out:
# <ipython-input-17-f925568c1af1>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste004'][count] = 1
# <ipython-input-17-f925568c1af1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste004'][count] = 2
# <ipython-input-17-f925568c1af1>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste004'][count] = 0

# %%
count = 0
countt = 0
while (countt < 1000):
  if (dfClass.iloc[countt]['Ternário'] == dfClass.iloc[countt]['teste004']):
    count = count + 1
  countt = countt + 1

count
# Out:
# 0

# %%
dfClass
# Out:
#     Unnamed: 0                       Date            User  \
# 0            0  2023-05-04 23:56:16+00:00         calotey
# 1            1  2023-05-04 23:41:15+00:00      Charloutt_
# 2            2  2023-05-04 23:40:07+00:00      sorenzitos
# 3            3  2023-05-04 22:55:38+00:00    lovers_ranpo
# 4            4  2023-05-04 22:40:02+00:00      _Wallkiri_
# ..         ...                        ...             ...
# 95          95  2023-05-03 22:15:55+00:00    mothisburned
# 96          96  2023-05-03 21:45:50+00:00   StarLight527w
# 97          97  2023-05-03 21:44:12+00:00        Noryzin2
# 98          98  2023-05-03 21:43:20+00:00  xichenlovepage
# 99          99  2023-05-03 21:41:50+00:00      Mathsukaze
#
#                                                 Tweet           ID  Binário  \
# 0     é absurdo como eu sou apaixonada pelo escotismo  1,65427E+18        1
# 1   Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 2   @ToinPierre Desbravador preservação, pela, bai...  1,65427E+18        0
# 3   @alyss0nz @i4geto É uma quantidade absurda e d...  1,65426E+18        0
# 4   @TalesMendes15 Lado bom esse mesmo, março e o ...  1,65425E+18        1
# ..                                                ...          ...      ...
# 95  desbravador(a) x sampo é esquisito em quesito ...  1,65389E+18        1
# 96  Oque é que nossos desbravadores tem de tão esp...  1,65388E+18        1
# 97  @eumechamonando Eu consegui levando natasha, h...  1,65388E+18        1
# 98                       vou sair dos escoteiros acho  1,65388E+18        0
# 99  @Isabell05916144 Pode deixar, o Desbravador nã...  1,65388E+18        1
#
#     Ternário  teste001  teste002  teste003  teste004
# 0          1         0         0         0         2
# 1          0         1         1         1         1
# 2          0         0         0         0         0
# 3          0         0         0         0         0
# 4          1         1         0         1         1
# ..       ...       ...       ...       ...       ...
# 95         1         0         0         1         1
# 96         1         0         0         1         0
# 97         1         1         1         1         1
# 98         0         0         0         1         0
# 99         1         0         0         0         0
#
# [100 rows x 11 columns]

# %%
##https://huggingface.co/lxyuan/distilbert-base-multilingual-cased-sentiments-student
unmasker005 = pipeline(model='lxyuan/distilbert-base-multilingual-cased-sentiments-student')
unmasker005("Feliz aniversário")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/759 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# [{'label': 'positive', 'score': 0.9404764771461487}]

# %%
dfClass['teste005'] = 1
count = 0

for tweet in dfClass['Tweet']:
  tweet_status = unmasker005(str(tweet))

  if (tweet_status[0]['label'] == 'positive'):
    dfClass['teste005'][count] = 1
  elif (tweet_status[0]['label'] == 'negative'):
    dfClass['teste005'][count] = 0
  else:
    dfClass['teste005'][count] = 2
  count = count + 1
# Out:
# <ipython-input-27-c20cc0b6ba51>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste005'][count] = 0
# <ipython-input-27-c20cc0b6ba51>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste005'][count] = 1
# <ipython-input-27-c20cc0b6ba51>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste005'][count] = 2

# %%
count = 0
countt = 0
while (countt < 1000):
  if (dfClass.iloc[countt]['Binário'] == dfClass.iloc[countt]['teste005']):
    count = count + 1
  countt = countt + 1

count
# Out:
# 59

# %%
unmasker006 = pipeline(model='lxyuan/distilbert-base-multilingual-cased-sentiments-student')
unmasker006("Feliz aniversário")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/759 [00:00<?, ?B/s]
# Downloading model.safetensors:   0%|          | 0.00/541M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# [{'label': 'positive', 'score': 0.9404764771461487}]

# %%
dfClass['teste006'] = 1
count = 0

for tweet in dfClass['Tweet']:
  tweet_status = unmasker006(str(tweet))

  if (tweet_status[0]['label'] == 'Positive'):
    dfClass['teste006'][count] = 1
  elif (tweet_status[0]['label'] == 'Negative'):
    dfClass['teste006'][count] = 0
  else:
    dfClass['teste006'][count] = 2
  count = count + 1
# Out:
# <ipython-input-8-94d1bad0bc87>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste006'][count] = 1
# <ipython-input-8-94d1bad0bc87>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste006'][count] = 0
# <ipython-input-8-94d1bad0bc87>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['teste006'][count] = 2

# %%
count = 0
countt = 0
while (countt < 100):
  if (dfClass.iloc[countt]['Ternário'] == dfClass.iloc[countt]['teste006']):
    count = count + 1
  countt = countt + 1

count
# Out:
# 22

# %% [markdown]
# #Testando o GPT

# %%
# !pip install python-dotenv requests
# Out:
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0

# %%
import os
import dotenv
import requests

# %%
dotenv.load_dotenv()

def analise_sentimento(text: str) -> str:
  modelo_engine = "text-davinci-003"
  comando = f"Responda em uma única palavra, sendo positivo ou negativo o sentimento contido no seguinte texto: '{text}'"

  cabecalho = {
      "Content-Type": "application/json",
      "Authorization": f"Bearer {'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'}",
  }

  dados = {
      "prompt": comando,
      "temperature": 0.7,
      "max_tokens": 35,
      "n": 1,
      "stop": None,
  }

  reposta = requests.post(
      f"https://api.openai.com/v1/engines/{modelo_engine}/completions",
      headers=cabecalho,
      json=dados,
 )

  return reposta.json()

# %%
analise_sentimento("Chato")
# Out:
# {'warning': 'This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations',
#  'id': 'cmpl-7oFh5YOByDwXhOo5ek4Yk6wtpMovK',
#  'object': 'text_completion',
#  'created': 1692211083,
#  'model': 'text-davinci-003',
#  'choices': [{'text': '\n\nNegativo.',
#    'index': 0,
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 39, 'completion_tokens': 6, 'total_tokens': 45}}

# %%
from time import sleep
dfClass['GPT'] = 1
count = 0
counttt = 0

for tweet in dfClass['Tweet']:
  try:
    if (counttt < 2):
      tweet_status = analise_sentimento(tweet)
      tweet_status = tweet_status["choices"][0]["text"].strip().lower()
      if (tweet_status == 'positivo.'):
        dfClass['GPT'][count] = 1
      elif (tweet_status == 'negativo.'):
        dfClass['GPT'][count] = 0
      else:
        dfClass['GPT'][count] = 2
      count = count + 1
      counttt = counttt + 1
    else:
      sleep(60)
      counttt = 0
  except:
    count = count + 1
    print(tweet_status)
    print(count)
    break
# Out:
# <ipython-input-34-a2857081dbcf>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['GPT'][count] = 0
# <ipython-input-34-a2857081dbcf>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfClass['GPT'][count] = 1
# {'error': {'message': 'Rate limit reached for default-text-davinci-003 in organization org-DlMPPHnl1M2WvhFasdTpgFPa on requests per day. Limit: 200 / day. Please try again in 7m12s. Contact us through our help center at help.openai.com if you continue to have issues. Please add a payment method to your account to increase your rate limit. Visit https://platform.openai.com/account/billing to add a payment method.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# 15

# %%
count
# Out:
# 3

# %%
count = 0
countt = 0
while (countt < 100):
  if (dfClass.iloc[countt]['Binário'] == dfClass.iloc[countt]['GPT']):
    count = count + 1
  countt = countt + 1

count
# Out:
# 80

# %%
dfClass
# Out:
#       Unnamed: 0                       Date             User  \
# 0              0  2023-05-04 23:41:15+00:00       Charloutt_
# 1              0  2023-05-04 23:56:16+00:00          calotey
# 2              1  2023-05-04 23:41:15+00:00       Charloutt_
# 3              2  2023-05-04 23:40:07+00:00       sorenzitos
# 4              3  2023-05-04 22:55:38+00:00     lovers_ranpo
# ...          ...                        ...              ...
# 996          995  2023-04-24 00:27:09+00:00          _missun
# 997          996  2023-04-24 00:25:13+00:00         hyagocos
# 998          997  2023-04-24 00:03:56+00:00   grosangeladias
# 999          998  2023-04-23 23:56:52+00:00          aclawrs
# 1000         999  2023-04-23 23:54:54+00:00  isacachinhos957
#
#                                                   Tweet           ID  Binário  \
# 0     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 1       é absurdo como eu sou apaixonada pelo escotismo  1,65427E+18        1
# 2     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 3     @ToinPierre Desbravador preservação, pela, bai...  1,65427E+18        1
# 4     @alyss0nz @i4geto É uma quantidade absurda e d...  1,65426E+18        0
# ...                                                 ...          ...      ...
# 996   Chorando com todas as publicações do dia do es...   1,6503E+18        1
# 997   A única parte ruim desse fds é que perdi a con...  1,65029E+18        0
# 998   @Escoteiros comida mateira com uma escoteira, ...  1,65029E+18        1
# 999                      hj é dia do escoteiro :( q sdd  1,65029E+18        0
# 1000  Minha prima linda(que nao esta falando comigo ...  1,65029E+18        1
#
#       Ternário  GPT
# 0          NaN    0
# 1          NaN    1
# 2          NaN    0
# 3          NaN    1
# 4          NaN    0
# ...        ...  ...
# 996        NaN    1
# 997        NaN    1
# 998        NaN    1
# 999        NaN    1
# 1000       NaN    1
#
# [1001 rows x 8 columns]

# %%
analise_sentimento("Lado bom esse mesmo, março e o desbravador tão upados, já tem utilidade kkkkkk")
# Out:
# 'neutro.'

# %%
list_gpt = []
count = 0
countt = 0
while (countt < 100):
  if (dfClass.iloc[countt]['Binário'] == dfClass.iloc[countt]['GPT']):
    count = count + 1
  else:
    list_gpt.append(countt)
  countt = countt + 1

list_gpt
# Out:
# [3, 13, 14, 20, 28, 34, 35, 38, 42, 47, 53, 59, 64, 67, 68, 72, 82, 87, 90, 98]

# %%
dfClass.iloc[35]['Tweet']
# Out:
# '@expressopompom Se possível do desbravador de fogo ?'

# %%
dfClass.iloc[35]['Binário']
# Out:
# 1

# %%
dfClass
# Out:
#       Unnamed: 0                       Date             User  \
# 0              0  2023-05-04 23:41:15+00:00       Charloutt_
# 1              0  2023-05-04 23:56:16+00:00          calotey
# 2              1  2023-05-04 23:41:15+00:00       Charloutt_
# 3              2  2023-05-04 23:40:07+00:00       sorenzitos
# 4              3  2023-05-04 22:55:38+00:00     lovers_ranpo
# ...          ...                        ...              ...
# 996          995  2023-04-24 00:27:09+00:00          _missun
# 997          996  2023-04-24 00:25:13+00:00         hyagocos
# 998          997  2023-04-24 00:03:56+00:00   grosangeladias
# 999          998  2023-04-23 23:56:52+00:00          aclawrs
# 1000         999  2023-04-23 23:54:54+00:00  isacachinhos957
#
#                                                   Tweet           ID  Binário  \
# 0     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 1       é absurdo como eu sou apaixonada pelo escotismo  1,65427E+18        1
# 2     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 3     @ToinPierre Desbravador preservação, pela, bai...  1,65427E+18        1
# 4     @alyss0nz @i4geto É uma quantidade absurda e d...  1,65426E+18        0
# ...                                                 ...          ...      ...
# 996   Chorando com todas as publicações do dia do es...   1,6503E+18        1
# 997   A única parte ruim desse fds é que perdi a con...  1,65029E+18        0
# 998   @Escoteiros comida mateira com uma escoteira, ...  1,65029E+18        1
# 999                      hj é dia do escoteiro :( q sdd  1,65029E+18        0
# 1000  Minha prima linda(que nao esta falando comigo ...  1,65029E+18        1
#
#       Ternário  teste003
# 0          NaN         1
# 1          NaN         0
# 2          NaN         1
# 3          NaN         0
# 4          NaN         0
# ...        ...       ...
# 996        NaN         1
# 997        NaN         0
# 998        NaN         1
# 999        NaN         1
# 1000       NaN         1
#
# [1001 rows x 8 columns]

# %% [markdown]
# 13, 28, 34

# %%
dfClass.to_excel('testep1000_001.xlsx')

# %% [markdown]
# #Verificações

# %%
# Acurácia
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
dfClass
# Out:
#       Unnamed: 0                       Date             User  \
# 0              0  2023-05-04 23:41:15+00:00       Charloutt_
# 1              0  2023-05-04 23:56:16+00:00          calotey
# 2              1  2023-05-04 23:41:15+00:00       Charloutt_
# 3              2  2023-05-04 23:40:07+00:00       sorenzitos
# 4              3  2023-05-04 22:55:38+00:00     lovers_ranpo
# ...          ...                        ...              ...
# 996          995  2023-04-24 00:27:09+00:00          _missun
# 997          996  2023-04-24 00:25:13+00:00         hyagocos
# 998          997  2023-04-24 00:03:56+00:00   grosangeladias
# 999          998  2023-04-23 23:56:52+00:00          aclawrs
# 1000         999  2023-04-23 23:54:54+00:00  isacachinhos957
#
#                                                   Tweet           ID  Binário  \
# 0     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 1       é absurdo como eu sou apaixonada pelo escotismo  1,65427E+18        1
# 2     Campori Osório 2022, um dos momentos da minha ...  1,65427E+18        0
# 3     @ToinPierre Desbravador preservação, pela, bai...  1,65427E+18        0
# 4     @alyss0nz @i4geto É uma quantidade absurda e d...  1,65426E+18        0
# ...                                                 ...          ...      ...
# 996   Chorando com todas as publicações do dia do es...   1,6503E+18        1
# 997   A única parte ruim desse fds é que perdi a con...  1,65029E+18        0
# 998   @Escoteiros comida mateira com uma escoteira, ...  1,65029E+18        1
# 999                      hj é dia do escoteiro :( q sdd  1,65029E+18        1
# 1000  Minha prima linda(que nao esta falando comigo ...  1,65029E+18        1
#
#       Ternário  teste003
# 0          NaN         1
# 1          NaN         0
# 2          NaN         1
# 3          NaN         0
# 4          NaN         0
# ...        ...       ...
# 996        NaN         1
# 997        NaN         0
# 998        NaN         1
# 999        NaN         1
# 1000       NaN         1
#
# [1001 rows x 8 columns]

# %%
acuracia = accuracy_score(dfClass['Binário'], dfClass['teste003'])
print('Acurácia: %f' % acuracia)
# Out:
# Acurácia: 0.873127

# %%
precision = precision_score(dfClass['Binário'], dfClass['teste003'])
print('Precision: %f' % precision)
# Out:
# Precision: 0.950980

# %%
recall = recall_score(dfClass['Binário'], dfClass['teste003'])
print('Recall: %f' % recall)
# Out:
# Recall: 0.857143

# %%
f1 = f1_score(dfClass['Binário'], dfClass['teste003'])
print('F1-Score: %f' % f1)
# Out:
# F1-Score: 0.901627
